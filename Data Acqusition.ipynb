# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("./information_leadership/ETF_Details.csv")
# Calculate percentage of NaN values for each column
nan_percentage = (df.isnull().sum() / len(df)) * 100
# Identify columns with > 80% NaN values
columns_to_drop = nan_percentage[nan_percentage > 80].index.tolist()
print(f"Dropping columns with >80% NaN: {columns_to_drop}")
# Drop those columns
df = df.drop(columns=columns_to_drop)
# Remove duplicate columns but keep one instance of each
df = df.loc[:, ~df.columns.duplicated()]
# Out:
# Dropping columns with >80% NaN: ['address', 'branding', 'currency_symbol', 'base_currency_name', 'base_currency_symbol', 'delisted_utc', 'description', 'ticker_suffix', 'homepage_url', 'market_cap', 'phone_number', 'sic_code', 'sic_description', 'total_employees', 'weighted_shares_outstanding']

# %%
### ETF Tickers
etf_tickers = "', '".join(df.ticker.tolist())

query = f"""
SELECT
  ticker,
  round(sum(size) / 1000000, 2) AS total_volume_shares_millions,
  round(sum(price*size) / 1000000, 2) AS total_volume_dollars_millions
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2024-11-04_filtered.parquet')
WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) >= '2024-10-08' 
  AND toDate(fromUnixTimestamp64Nano(participant_timestamp)) <= '2024-11-04'
  AND ticker IN ('{etf_tickers}') AND ticker NOT IN ('IBIT')
GROUP BY ticker
ORDER BY total_volume_dollars_millions DESC
LIMIT 20
FORMAT Markdown
"""
print(query)

### Stock Tickers
stocks_df = pd.read_csv("/home/grego/Alphathon/fama/All_Stock_Tickers.csv")
stocks_df = stocks_df[(stocks_df.locale == "us") & (stocks_df.type == "CS")]
# Convert to string and filter out NaN values
stock_tickers = "', '".join(stocks_df.ticker.dropna().astype(str).tolist())

query = f"""
SELECT
  ticker,
  round(sum(size) / 1000000, 2) AS total_volume_shares_millions,
  round(sum(price*size) / 1000000, 2) AS total_volume_dollars_millions
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2024-11-04_filtered.parquet')
WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) >= '2024-10-08' 
  AND toDate(fromUnixTimestamp64Nano(participant_timestamp)) <= '2024-11-04'
  AND ticker IN ('{stock_tickers}')
GROUP BY ticker
ORDER BY total_volume_dollars_millions DESC
LIMIT 20
FORMAT Markdown
"""

print(query)
# Out:
# SELECT
#   ticker,
#   round(sum(size) / 1000000, 2) AS total_volume_shares_millions,
#   round(sum(price*size) / 1000000, 2) AS total_volume_dollars_millions
# FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2024-11-04_filtered.parquet')
# WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) >= '2024-10-08'
#   AND toDate(fromUnixTimestamp64Nano(participant_timestamp)) <= '2024-11-04'
#   AND ticker IN ('AAA', 'AAAA', 'AAAU', 'AADR', 'AALG', 'AAPB', 'AAPD', 'AAPR', 'AAPU', 'AAPW', 'AAPX', 'AAPY', 'AAUS', 'AAVM', 'AAXJ', 'ABCS', 'ABEQ', 'ABFL', 'ABI', 'ABIG', 'ABLD', 'ABLG', 'ABLS', 'ABOT', 'ABXB', 'ACEI', 'ACES', 'ACGR', 'ACII', 'ACIO', 'ACKY', 'ACLC', 'ACLO', 'ACSI', 'ACTV', 'ACVF', 'ACVT', 'ACWI', 'ACWV', 'ACWX', 'ADBG', 'ADFI', 'ADIV', 'ADME', 'ADPV', 'ADVE', 'AEMS', '
# GROUP BY ticker
# ORDER BY total_volume_dollars_millions DESC
# LIMIT 20
# FORMAT Markdown
#
#
# SELECT
#   ticker,
#   round(sum(size) / 1000000, 2) AS total_volume_shares_millions,
#   round(sum(price*size) / 1000000, 2) AS total_volume_dollars_millions
# FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2024-11-04_filtered.parquet')
# WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) >= '2024-10-08'
#   AND toDate(fromUnixTimestamp64Nano(participant_timestamp)) <= '2024-11-04'
#   AND ticker IN ('A', 'AA', 'AACB', 'AACI', 'AAL', 'AAM', 'AAME', 'AAMI', 'AAOI', 'AAON', 'AAP', 'AAPL', 'AARD', 'AAT', 'AAUC', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABEO', 'ABG', 'ABL', 'ABLLL', 'ABLV', 'ABM', 'ABNB', 'ABOS', 'ABP', 'ABR', 'ABSI', 'ABT', 'ABTC', 'ABTS', 'ABUS', 'ABVC', 'ABVE', 'ACA', 'ACAD', 'ACB', 'ACCO', 'ACCS', 'ACDC', 'ACEL', 'ACET', 'ACFN', 'ACGL', 'ACGLN', 'ACHC', 'ACHR', 'ACHV', 'ACI', 'ACIC', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACOG', 'ACON', 'ACR', 'ACRE', 'ACRS', 'ACRV', 'ACT', 'ACTG', 'ACTU', 'ACU', 'ACVA', 'ACXP', 'AD', 'ADAM', 'ADAMG', 'ADAMH', 'ADAMI', 'ADAML', 'ADAMZ', 'ADBE', 'ADC', 'ADCT', 'ADEA', 'ADGM', 'ADI', 'ADIL', 'ADM', 'ADMA', 'ADN', 'ADNT', 'ADP', 'ADPT', 'ADSE', 'ADSK', 'ADT', 'ADTN', 'ADTX', 'ADUR', 'ADUS', 'ADV', 'ADVB', 'ADVM', 'AEBI', 'AEC', 'AEE', 'AEG', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEM', 'AEMD', 'AENT', 'AEO', 'AEON', 'AEP', 'AER', 'AERT', 'AES', 'AESI', 'AEVA', 'AEXA', 'AEYE', 'AFBI', 'AFCG', 'AFG', 'AFJK', 'AFL', 'AFRI', 'AFRM', 'AFYA', 'AG', 'AGAE', 'AGCO', 'AGEN', 'AGH', 'AGI', 'AGIO', 'AGL', 'AGM', 'AGM.A', 'AGMH', 'AGNC', 'AGNCL', 'AGNCO', 'AGO', 'AGRI', 'AGRO', 'AGX', 'AGYS', 'AHCO', 'AHH', 'AHL', 'AHR', 'AHT', 'AI', 'AIFF', 'AIFU', 'AIG', 'AIHS', 'AII', 'AIIO', 'AIM', 'AIMD', 'AIN', 'AIOT', 'AIP', 'AIR', 'AIRE', 'AIRG', 'AIRI', 'AIRJ', 'AIRO', 'AIRS', 'AIRT', 'AISP', 'AIT', 'AIV', 
'ASTL', 'ASTS', 'ASUR', 'ASYS', 'ATAI', 'ATCH', 'ATEC', 'ATEN', 'ATER', 'ATEX', 'ATGE', 'ATGL', 'ATHA', 'ATHR', 'ATI', 'ATII', 'ATKR', 'ATLC', 'ATLCL', 'ATLCZ', 'ATLN', 'ATLO', 'ATLX', 'ATMC', 'ATMU', 'ATMV', 'ATNI', 'ATNM', 'ATO', 'ATOM', 'ATON', 'ATOS', 'ATPC', 'ATR', 'ATRA', 'ATRC', 'ATRO', 'ATS', 'ATUS', 'ATXG', 'ATXS', 'ATYR', 'AU', 'AUB', 'AUBN', 'AUDC', 'AUGO', 'AUID', 'AUNA', 'AUPH', 'AUR', 'AURA', 'AUST', 'AUUD', 'AVA', 'AVAH', 'AVAV', 'AVB', 'AVBC', 'AVBH', 'AVBP', 'AVD', 'AVDL', 'AVDX', 'AVGO', 'AVIR', 'AVNS', 'AVNT', 'AVNW', 'AVO', 'AVPT', 'AVR', 'AVT', 'AVTR', 'AVTX', 'AVXL', 'AVY', 'AWI', 'AWK', 'AWR', 'AWRE', 'AWX', 'AX', 'AXGN', 'AXIL', 'AXIN', 'AXL', 'AXON', 'AXP', 'AXR', 'AXS', 'AXSM', 'AXTA', 'AXTI', 'AYI', 'AYTU', 'AZ', 'AZI', 'AZO', 'AZTA', 'AZTR', 'AZZ', 'B', 'BA', 'BAC', 'BACC', 'BACQ',  ...
# GROUP BY ticker
# ORDER BY total_volume_dollars_millions DESC
# LIMIT 20
# FORMAT Markdown

# %% [markdown]
# ## Query Result : Top 20 ETFs By Volume for the 20 Trading Days Ending 2024-11-04, Inclusive. (IBIT made it in here, but they don't have options expiring on 2024-11-15)
#
# | ticker | total_volume_shares_millions | total_volume_dollars_millions |
# |:-|-:|-:|
# | SPY | 42.97 | 24508.73 |
# | QQQ | 23.73 | 11553.67 |
# | TLT | 58.64 | 5404.76 |
# | IWM | 22.32 | 4917.82 |
# | LQD | 29.14 | 3170.3 |
# | IVV | 5.13 | 2938.15 |
# | TQQQ | 41.32 | 2919.48 |
# | HYG | 29.4 | 2322.12 |
# | FXI | 69.3 | 2215.29 |
# | VUG | 5.61 | 2162.81 |
# | VOO | 4.12 | 2161.13 |
# | XLF | 44.72 | 2070.11 |
# | SOXL | 63.82 | 1967.29 |
# | XLE | 16.3 | 1457.6 |
# | DIA | 3.29 | 1376.73 |
# | EEM | 29.22 | 1311.22 |
# | SMH | 5.28 | 1295.24 |
# | SQQQ | 167.5 | 1251.94 |
# | XLU | 15.25 | 1177.37 |
# | KRE | 19.76 | 1148.03 |
#
# ## Query Result : Top 20 Equities By Volume for the 20 Trading Days Ending 2024-11-04, Inclusive
#
# | ticker | total_volume_shares_millions | total_volume_dollars_millions |
# |:-|-:|-:|
# | NVDA | 199.94 | 27455.7 |
# | TSLA | 71.87 | 17547.06 |
# | AAPL | 53.95 | 11966.04 |
# | MSFT | 25.17 | 10280.08 |
# | AMZN | 42.35 | 8299.58 |
# | META | 13.69 | 7700.17 |
# | AMD | 31.01 | 4388.74 |
# | GOOGL | 24.76 | 4190.84 |
# | LLY | 5.12 | 4140.44 |
# | DJT | 120.09 | 3918.52 |
# | PLTR | 80.25 | 3445.03 |
# | BRK.B | 7.51 | 3320.25 |
# | MSTR | 14.32 | 3235.76 |
# | GOOG | 18.85 | 3217.78 |
# | AVGO | 16.52 | 2799.68 |
# | XOM | 23.45 | 2775.06 |
# | CEG | 11.2 | 2576.09 |
# | JPM | 11.66 | 2569.49 |
# | SMCI | 95.07 | 2503.97 |
# | SHW | 6.51 | 2440.14 |

# %%
import json

# Top 20 ETFs by volume
top_20_etfs = [
    "SPY",
    "QQQ",
    "TLT",
    "IWM",
    "LQD",
    "IVV",
    "TQQQ",
    "HYG",
    "FXI",
    "VUG",
    "VOO",
    "XLF",
    "SOXL",
    "XLE",
    "DIA",
    "EEM",
    "SMH",
    "SQQQ",
    "XLU",
    "KRE",
]
# Top 20 equities by volume
top_20_stocks = [
    "NVDA",
    "TSLA",
    "AAPL",
    "MSFT",
    "AMZN",
    "META",
    "AMD",
    "GOOGL",
    "LLY",
    "DJT",
    "PLTR",
    "BRK.B",
    "MSTR",
    "GOOG",
    "AVGO",
    "XOM",
    "CEG",
    "JPM",
    "SMCI",
    "SHW",
]
# Save to JSON file
selected_instruments = {"selected_stocks": top_20_stocks, "selected_ETFs": top_20_etfs}
with open("instrument_selected_instruments.json", "w") as f:
    json.dump(selected_instruments, f, indent=2)

# %%
import pandas_market_calendars as mcal

# Create a calendar
nyse = mcal.get_calendar("NASDAQ")
# Show available calendars
trading_days = nyse.schedule(
    start_date="2024-10-08", end_date="2024-11-04"
).index.tolist()
trading_days = [day.strftime("%Y-%m-%d") for day in trading_days]

# %%
from clickhouse_connect import get_client

client = get_client()


def insert_kalshi_data(date):
    query = f"""
    INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/kalshi_election/{date}.parquet')
    SELECT
        ticker_name AS symbol,
        parseDateTime64BestEffort(create_ts, 3, 'America/New_York') AS timestamp,
        contracts_traded,
        price
    FROM kalshi_reported_trades
    WHERE toDate(timestamp) = '{date}' AND symbol LIKE 'PRES-2024-%'
    ORDER BY timestamp ASC
    SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16, s3_truncate_on_insert=1
    """
    client.command(query)

# %%
from tqdm.auto import tqdm

for date in tqdm(
    trading_days + ["2024-11-05"]
):  # We want the date of the election itself for realtime use in CSP1
    insert_kalshi_data(date)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
from tqdm.auto import tqdm

TICKER_FILTER = "','".join(
    selected_instruments["selected_stocks"] + selected_instruments["selected_ETFs"]
)
TICKER_FILTER = f"('{TICKER_FILTER}')"

# Create comma-separated list of dates for the glob pattern
date_pattern = ",".join(trading_days[:20])
client = get_client()

insert_trades_query = f"""
CREATE TABLE alphathon_trades
ENGINE = MergeTree()
ORDER BY (ticker, participant_timestamp)
SETTINGS allow_nullable_key = 1
AS
SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/{{{date_pattern}}}_filtered.parquet')
WHERE ticker IN {TICKER_FILTER}
SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16
"""
print(insert_trades_query)

insert_quotes_query = f"""
CREATE TABLE alphathon_quotes
ENGINE = MergeTree()
ORDER BY (ticker, participant_timestamp)
SETTINGS allow_nullable_key = 1
AS
SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_quotes/{{{date_pattern}}}_filtered.parquet')
WHERE ticker IN {TICKER_FILTER}
SETTINGS max_threads=32, max_insert_threads=32, max_download_threads=32
"""
print(insert_quotes_query)
# Out:
# CREATE TABLE alphathon_trades
# ENGINE = MergeTree()
# ORDER BY (ticker, participant_timestamp)
# SETTINGS allow_nullable_key = 1
# AS
# SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/{2024-10-08,2024-10-09,2024-10-10,2024-10-11,2024-10-14,2024-10-15,2024-10-16,2024-10-17,2024-10-18,2024-10-21,2024-10-22,2024-10-23,2024-10-24,2024-10-25,2024-10-28,2024-10-29,2024-10-30,2024-10-31,2024-11-01,2024-11-04}_filtered.parquet')
# WHERE ticker IN ('NVDA','TSLA','AAPL','MSFT','AMZN','META','AMD','GOOGL','LLY','DJT','PLTR','BRK.B','MSTR','GOOG','AVGO','XOM','CEG','JPM','SMCI','SHW','SPY','QQQ','TLT','IWM','LQD','IVV','TQQQ','HYG','FXI','VUG','VOO','XLF','SOXL','XLE','DIA','EEM','SMH','SQQQ','XLU','KRE')
# SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16
#
#
# CREATE TABLE alphathon_quotes
# ENGINE = MergeTree()
# ORDER BY (ticker, participant_timestamp)
# SETTINGS allow_nullable_key = 1
# AS
# SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_quotes/{2024-10-08,2024-10-09,2024-10-10,2024-10-11,2024-10-14,2024-10-15,2024-10-16,2024-10-17,2024-10-18,2024-10-21,2024-10-22,2024-10-23,2024-10-24,2024-10-25,2024-10-28,2024-10-29,2024-10-30,2024-10-31,2024-11-01,2024-11-04}_filtered.parquet')
# WHERE ticker IN ('NVDA','TSLA','AAPL','MSFT','AMZN','META','AMD','GOOGL','LLY','DJT','PLTR','BRK.B','MSTR','GOOG','AVGO','XOM','CEG','JPM','SMCI','SHW','SPY','QQQ','TLT','IWM','LQD','IVV','TQQQ','HYG','FXI','VUG','VOO','XLF','SOXL','XLE','DIA','EEM','SMH','SQQQ','XLU','KRE')
# SETTINGS max_threads=32, max_insert_threads=32, max_download_threads=32

# %%
from clickhouse_connect import get_client
import json
from tqdm import tqdm

with open("/home/grego/Alphathon/instrument_selected_instruments.json", "r") as f:
    selected_instruments = json.load(f)

all_tickers = (
    selected_instruments["selected_stocks"] + selected_instruments["selected_ETFs"]
)


ROOTS = [
    "AAPL",
    "AMD",
    "AMZN",
    "AVGO",
    "BRKB",
    "CEG",
    "DIA",
    "DJT",
    "EEM",
    "FXI",
    "GOOG",
    "GOOGL",
    "HYG",
    "IVV",
    "IWM",
    "JPM",
    "KRE",
    "LLY",
    "LQD",
    "META",
    "MSFT",
    "MSTR",
    "NVDA",
    "PLTR",
    "QQQ",
    "SHW",
    "SMCI",
    "SMH",
    "SOXL",
    "SPY",
    "SQQQ",
    "TLT",
    "TQQQ",
    "TSLA",
    "VOO",
    "VUG",
    "XLE",
    "XLF",
    "XLU",
    "XOM",
]

client = get_client()

for ROOT in tqdm(ROOTS):
    query = f"""
INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected_formatted/{ROOT}_20241115_20241105_20241105_1000.parquet')
SELECT
    root AS symbol,
    toDateTime64(date / 1000 + ms_of_day / 1000.0, 3, 'America/New_York') AS timestamp,
    root AS underlying,
    exp AS expiration,
    CAST(strike AS Float64) AS strike,
    right AS right,
    bid_size AS bid_size,
    bid_exchange AS bid_exchange,
    bid AS bid,
    bid_condition AS bid_condition,
    ask_size AS ask_size,
    ask_exchange AS ask_exchange,
    ask AS ask,
    ask_condition AS ask_condition
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected/{ROOT}_20241115_20241105_20241105_1000.parquet')
"""
    client.command(query)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 42
#      22 for ROOT in tqdm(ROOTS):
#      23     query = f"""
#      24 INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected_formatted/{ROOT}_20241115_20241105_20241105_1000.parquet')
#      25 SELECT
#    (...)     40 FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected/{ROOT}_20241115_20241105_20241105_1000.parquet')
#      41 """
# ---> 42     client.command(query)
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:412, in HttpClient.command(self, cmd, parameters, data, settings, use_database, external_data, transport_settings)
#     410 headers = dict_copy(headers, transport_settings)
#     411 method = 'POST' if payload or fields else 'GET'
# --> 412 response = self._raw_request(payload, params, headers, method, fields=fields, server_wait=False)
#     413 if response.data:
#     414     try:
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:547, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler)
#     545     error_handler(response)
#     546 else:
# --> 547     self._error_handler(response)
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:468, in HttpClient._error_handler(self, response, retried)
#     465     response.close()
#     467 # Raise the appropriate exception class
# --> 468 raise OperationalError(err_str) if retried else DatabaseError(err_str) from None
#
# DatabaseError: Received ClickHouse exception, code: 36, server response: Code: 36. DB::Exception: Object in bucket GregsMktData with key AlphathonDatasets/options_selected_formatted/AAPL_20241115_20241105_20241105_1000.parquet already exists. If you want to overwrite it, enable setting s3_truncate_on_insert, if you want to create a new file on each insert, enable setting s3_create_new_file_on_insert. (BAD_ARGUMENTS) (version 25.5.2.47 (official build)) (for url http://localhost:8123)

# %%
from clickhouse_connect import get_client
from tqdm import tqdm

ROOTS = [
    "AAPL",
    "AMD",
    "AMZN",
    "AVGO",
    "BRKB",
    "CEG",
    "DIA",
    "DJT",
    "EEM",
    "FXI",
    "GOOG",
    "GOOGL",
    "HYG",
    "IVV",
    "IWM",
    "JPM",
    "KRE",
    "LLY",
    "LQD",
    "META",
    "MSFT",
    "MSTR",
    "NVDA",
    "PLTR",
    "QQQ",
    "SHW",
    "SMCI",
    "SMH",
    "SOXL",
    "SPY",
    "SQQQ",
    "TLT",
    "TQQQ",
    "TSLA",
    "VOO",
    "VUG",
    "XLE",
    "XLF",
    "XLU",
    "XOM",
]

client = get_client()

for ROOT in tqdm(ROOTS):
    query = f"""
INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected_formatted/{ROOT}_20241115_20241105_20241105_1000.parquet')
SELECT
    root AS symbol,
    toDateTime64(toInt64(date) + ms_of_day / 1000.0, 3, 'America/New_York') AS timestamp,
    toDateTime64(exp / 1000000000, 9, 'America/New_York') AS expiration,
    CAST(strike AS Float64) AS strike,
    right AS right,
    bid_size AS bid_size,
    bid_exchange AS bid_exchange,
    bid AS bid,
    bid_condition AS bid_condition,
    ask_size AS ask_size,
    ask_exchange AS ask_exchange,
    ask AS ask,
    ask_condition AS ask_condition,
    concat(
        leftPad(root, 6, ' '),
        formatDateTime(toDateTime64(exp / 1000000000, 9, 'America/New_York'), '%y%m%d'),
        upper(right),
        leftPad(toString(toInt64(strike * 1000)), 8, '0')
    ) AS occ_symbol
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected/{ROOT}_20241115_20241105_20241105_1000.parquet')
SETTINGS s3_truncate_on_insert=1
"""
    client.command(query)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
#  60%|██████    | 24/40 [00:38<00:25,  1.61s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 40
#      14 for ROOT in tqdm(ROOTS):
#      15     query = f"""
#      16 INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/options_selected_formatted/{ROOT}_20241115_20241105_20241105_1000.parquet')
#      17 SELECT
#    (...)     38 SETTINGS s3_truncate_on_insert=1
#      39 """
# ---> 40     client.command(query)
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:412, in HttpClient.command(self, cmd, parameters, data, settings, use_database, external_data, transport_settings)
#     410 headers = dict_copy(headers, transport_settings)
#     411 method = 'POST' if payload or fields else 'GET'
# --> 412 response = self._raw_request(payload, params, headers, method, fields=fields, server_wait=False)
#     413 if response.data:
#     414     try:
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:522, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler)
#     520     self._active_session = query_session
#     521 try:
# --> 522     response = self.http.request(method, url, **kwargs)
#     523 except HTTPError as ex:
#     524     if isinstance(ex.__context__, ConnectionResetError):
#     525         # The server closed the connection, probably because the Keep Alive has expired
#     526         # We should be safe to retry, as ClickHouse should not have processed anything on a connection
#     527         # that it killed.  We also only retry this once, as multiple disconnects are unlikely to be
#     528         # related to the Keep Alive settings
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/urllib3/poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.12.10/envs/alpha/lib/python3.12/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.12.10/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# #### `quotes_selected`

# %%
insert_selected_quotes_query = """
INSERT INTO FUNCTION s3
(
'https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/quotes_selected/2024-11-05.parquet'
)
SELECT 
    ticker AS symbol,
    ask_exchange,
    ask_price,
    ask_size,
    bid_exchange,
    bid_price,
    bid_size,
    conditions,
    indicators,
    fromUnixTimestamp64Nano(participant_timestamp) AS timestamp,
    sequence_number,
    sip_timestamp,
    tape,
    trf_timestamp
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_quotes/2024-11-05_filtered.parquet')
WHERE ticker IN ('NVDA','TSLA','AAPL','MSFT','AMZN','META','AMD','GOOGL','LLY','DJT','PLTR','BRK.B','MSTR','GOOG','AVGO','XOM','CEG','JPM','SMCI','SHW','SPY','QQQ','TLT','IWM','LQD','IVV','TQQQ','HYG','FXI','VUG','VOO','XLF','SOXL','XLE','DIA','EEM','SMH','SQQQ','XLU','KRE')
SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16
"""

insert_selected_trades_query = """
INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/AlphathonDatasets/trades_selected/2024-11-05.parquet')
SELECT 
    ticker AS symbol,
    conditions,
    correction,
    exchange,
    id,
    fromUnixTimestamp64Nano(participant_timestamp) AS timestamp,
    price,
    sequence_number,
    sip_timestamp,
    size,
    tape,
    trf_id,
    trf_timestamp
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2024-11-05_filtered.parquet')
WHERE ticker IN ('NVDA','TSLA','AAPL','MSFT','AMZN','META','AMD','GOOGL','LLY','DJT','PLTR','BRK.B','MSTR','GOOG','AVGO','XOM','CEG','JPM','SMCI','SHW','SPY','QQQ','TLT','IWM','LQD','IVV','TQQQ','HYG','FXI','VUG','VOO','XLF','SOXL','XLE','DIA','EEM','SMH','SQQQ','XLU','KRE')
SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16
"""

# %% [markdown]
# CREATE TABLE alphathon_quotes

# %%
queries = []
for date_str in trading_days[:20]:
    query = f"""
    WITH quote_data AS (
        SELECT
            *,
            fromUnixTimestamp64Nano(participant_timestamp) AS ts,
            0.5 * (bid_price + ask_price) AS mid_price,
            log(mid_price) AS log_mid,
            (ask_price - bid_price) / mid_price AS rsprd,
            intDiv(participant_timestamp, 1e7) AS bucket
        FROM alphathon_quotes
        WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) = '{date_str}'
        AND (100*toHour(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York') + toMinute(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York')) BETWEEN 930 AND 1559
    ),
    grouped_quote_data AS (
        SELECT
            ticker,
            bucket,
            fromUnixTimestamp64Nano(toInt64((bucket)*1e7)) AS bucket_ts,
            argMax(log_mid, participant_timestamp) AS log_mid,
            count(*) AS quote_updates,
            avg(rsprd) AS avg_rsprd
        FROM quote_data
        GROUP BY ticker, bucket
    ),
    trades AS (
        SELECT
            *,
            fromUnixTimestamp64Nano(participant_timestamp) AS ts
        FROM alphathon_trades
        WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) = '{date_str}'
        AND (100*toHour(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York') + toMinute(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York')) BETWEEN 930 AND 1559
    ),
    quotes AS (
        SELECT
            *,
            fromUnixTimestamp64Nano(participant_timestamp) AS ts,
            0.5 * (bid_price + ask_price) AS mid_price
        FROM alphathon_quotes
        WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) = '{date_str}'
        AND (100*toHour(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York') + toMinute(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York')) BETWEEN 930 AND 1559
    ),
    trades_with_quotes AS (
        SELECT 
            t.*,
            q.bid_price,
            q.ask_price,
            q.mid_price,
            intDiv(t.participant_timestamp, 1e7) AS bucket,
            CASE 
                WHEN t.price > q.mid_price THEN t.size
                WHEN t.price < q.mid_price THEN -t.size
                ELSE 0
            END AS taker_flow,
            CASE 
                WHEN conditions LIKE '%14%' AND t.price > q.mid_price THEN t.size
                WHEN conditions LIKE '%14%' AND t.price < q.mid_price THEN -t.size
                ELSE 0
            END AS taker_flow_iso,
            CASE 
                WHEN conditions LIKE '%14%' THEN 1
                ELSE 0
            END AS is_iso
        FROM trades t
        ASOF LEFT JOIN quotes q 
            ON t.ticker = q.ticker 
            AND q.participant_timestamp <= t.participant_timestamp
    ),
    grouped_trade_data AS (
        SELECT
            ticker,
            bucket,
            fromUnixTimestamp64Nano(toInt64((bucket)*1e7)) AS bucket_ts,
            sum(is_iso) / nullIf(count(*), 0) AS pct_trades_iso,
            sum(CASE WHEN is_iso = 1 THEN size ELSE 0 END) / nullIf(sum(size), 0) AS pct_volume_iso,
            sum(CASE WHEN is_iso = 0 THEN taker_flow ELSE 0 END) AS total_flow_non_iso,
            sum(taker_flow_iso) AS total_flow_iso,
            count(*) AS num_trades,
            sum(is_iso) AS num_trades_iso,
            sum(size) AS total_volume
        FROM trades_with_quotes
        GROUP BY ticker, bucket
    ),
    combined_features AS (
        SELECT
            COALESCE(q.ticker, t.ticker) AS ticker,
            COALESCE(q.bucket_ts, t.bucket_ts) AS bucket_ts,
            COALESCE(q.bucket, t.bucket) AS bucket,
            q.log_mid,
            q.quote_updates,
            q.avg_rsprd,
            t.pct_trades_iso,
            t.pct_volume_iso,
            t.total_flow_non_iso,
            t.total_flow_iso,
            t.num_trades,
            t.num_trades_iso,
            t.total_volume,
            t.total_flow_non_iso + t.total_flow_iso AS total_flow,
            CASE WHEN t.total_volume > 0 THEN abs(t.total_flow_iso) / t.total_volume ELSE 0 END AS iso_flow_intensity
        FROM grouped_quote_data q
        FULL OUTER JOIN grouped_trade_data t 
            ON q.ticker = t.ticker 
            AND q.bucket_ts = t.bucket_ts
    )
    INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/pre-elec-{date_str}.parquet')
    SELECT * 
    FROM combined_features
    WHERE ticker IS NOT NULL 
    AND bucket_ts IS NOT NULL
    ORDER BY ticker, bucket_ts
    SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16, s3_truncate_on_insert=1
    """
    queries.append(query)

for query in tqdm(queries):
    client = get_client()
    client.command(query)

# %%
print(queries[0])
# Out:
#     WITH quote_data AS (
#         SELECT
#             *,
#             fromUnixTimestamp64Nano(participant_timestamp) AS ts,
#             0.5 * (bid_price + ask_price) AS mid_price,
#             log(mid_price) AS log_mid,
#             (ask_price - bid_price) / mid_price AS rsprd,
#             intDiv(participant_timestamp, 1e7) AS bucket
#         FROM alphathon_quotes
#         WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) = '2024-10-08'
#         AND (100*toHour(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York') + toMinute(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York')) BETWEEN 930 AND 1559
#     ),
#     grouped_quote_data AS (
#         SELECT
#             ticker,
#             bucket,
#             fromUnixTimestamp64Nano(toInt64((bucket)*1e7)) AS bucket_ts,
#             argMax(log_mid, participant_timestamp) AS log_mid,
#             count(*) AS quote_updates,
#             avg(rsprd) AS avg_rsprd
#         FROM quote_data
#         GROUP BY ticker, bucket
#     ),
#     trades AS (
#         SELECT
#             *,
#             fromUnixTimestamp64Nano(participant_timestamp) AS ts
#         FROM alphathon_trades
#         WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) = '2024-10-08'
#         AND (100*toHour(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York') + toMinute(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York')) BETWEEN 930 AND 1559
#     ),
#     quotes AS (
#         SELECT
#             *,
#             fromUnixTimestamp64Nano(participant_timestamp) AS ts,
#             0.5 * (bid_price + ask_price) AS mid_price
#         FROM alphathon_quotes
#         WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) = '2024-10-08'
#         AND (100*toHour(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York') + toMinute(fromUnixTimestamp64Nano(participant_timestamp), 'America/New_York')) BETWEEN 930 AND 1559
#     ),
#     trades_with_quotes AS (
#         SELECT
#             t.*,
#             q.bid_price,
#             q.ask_price,
#             q.mid_price,
#             intDiv(t.participant_timestamp, 1e7) AS bucket,
#             CASE
#                 WHEN t.price > q.mid_price THEN t.size
#                 WHEN t.price < q.mid_price THEN -t.size
#                 ELSE 0
#             END AS taker_flow,
#             CASE
#                 WHEN conditions LIKE '%14%' AND t.price > q.mid_price THEN t.size
#                 WHEN conditions LIKE '%14%' AND t.price < q.mid_price THEN -t.size
#                 ELSE 0
#             END AS taker_flow_iso,
#             CASE
#                 WHEN conditions LIKE '%14%' THEN 1
#                 ELSE 0
#             END AS is_iso
#         FROM trades t
#         ASOF LEFT JOIN quotes q
#             ON t.ticker = q.ticker
#             AND q.participant_timestamp <= t.participant_timestamp
#     ),
#     grouped_trade_data AS (
#         SELECT
#             ticker,
#             bucket,
#             fromUnixTimestamp64Nano(toInt64((bucket)*1e7)) AS bucket_ts,
#             sum(is_iso) / nullIf(count(*), 0) AS pct_trades_iso,
#             sum(CASE WHEN is_iso = 1 THEN size ELSE 0 END) / nullIf(sum(size), 0) AS pct_volume_iso,
#             sum(CASE WHEN is_iso = 0 THEN taker_flow ELSE 0 END) AS total_flow_non_iso,
#             sum(taker_flow_iso) AS total_flow_iso,
#             count(*) AS num_trades,
#             sum(is_iso) AS num_trades_iso,
#             sum(size) AS total_volume
#         FROM trades_with_quotes
#         GROUP BY ticker, bucket
#     ),
#     combined_features AS (
#         SELECT
#             COALESCE(q.ticker, t.ticker) AS ticker,
#             COALESCE(q.bucket_ts, t.bucket_ts) AS bucket_ts,
#             COALESCE(q.bucket, t.bucket) AS bucket,
#             q.log_mid,
#             q.quote_updates,
#             q.avg_rsprd,
#             t.pct_trades_iso,
#             t.pct_volume_iso,
#             t.total_flow_non_iso,
#             t.total_flow_iso,
#             t.num_trades,
#             t.num_trades_iso,
#             t.total_volume,
#             t.total_flow_non_iso + t.total_flow_iso AS total_flow,
#             CASE WHEN t.total_volume > 0 THEN abs(t.total_flow_iso) / t.total_volume ELSE 0 END AS iso_flow_intensity
#         FROM grouped_quote_data q
#         FULL OUTER JOIN grouped_trade_data t
#             ON q.ticker = t.ticker
#             AND q.bucket_ts = t.bucket_ts
#     )
#     INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/pre-elec-2024-10-08.parquet')
#     SELECT *
#     FROM combined_features
#     WHERE ticker IS NOT NULL
#     AND bucket_ts IS NOT NULL
#     ORDER BY ticker, bucket_ts
#     SETTINGS max_threads=16, max_insert_threads=16, max_download_threads=16, s3_truncate_on_insert=1

# %%
),

# %% [markdown]
# ## Union of Top 20 ETFs and Top 20 Equities by Volume
# ('AAPL', 'AMD', 'AMZN', 'AVGO', 'BRK.B', 'CEG', 'DIA', 'DJT', 'EEM', 'FXI', 'GOOG', 'GOOGL', 'HYG', 'IBIT', 'IVV', 'IWM', 'JPM', 'LLY', 'LQD', 'META', 'MSTR', 'MSFT', 'NVDA', 'PLTR', 'QQQ', 'SMCI', 'SMH', 'SOXL', 'SQQQ', 'SPY', 'TLT', 'TQQQ', 'TSLA', 'VOO', 'VUG', 'XLE', 'XLF', 'XLU', 'XOM')

# %%
tickers_list = "', '".join(df.ticker.tolist())

query = f"""
SELECT
  ticker,
  sum(size) AS total_volume_shares,
  sum(price*size) AS total_volume_dollars
FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2024-11-04_filtered.parquet')
WHERE toDate(fromUnixTimestamp64Nano(participant_timestamp)) >= '2024-10-08' 
  AND toDate(fromUnixTimestamp64Nano(participant_timestamp)) <= '2024-11-04'
  AND ticker IN ('{tickers_list}')
GROUP BY ticker
ORDER BY total_volume_dollars DESC
LIMIT 20
"""

# %%
xnas = df[df.primary_exchange == "XNAS"].sort_values(
    by="share_class_shares_outstanding", ascending=False
)
# xnas = xnas[xnas.share_class_shares_outstanding > 1e8]
# xnas = xnas[~xnas.name.str.contains('Bond', case=False, na=False)]
# xnas = xnas[~xnas.name.str.contains('Bitcoin', case=False, na=False)]
# xnas = xnas[~xnas.name.str.contains('Treasury', case=False, na=False)]
# xnas = xnas[~xnas.name.str.contains('Fixed Income', case=False, na=False)]

pd.set_option("display.max_rows", None)
xnas[xnas.share_class_shares_outstanding > 1e8]
# Out:
#       Unnamed: 0 ticker                                               name  \
# 376          376    BND                         Vanguard Total Bond Market
# 4034        4034   VXUS             Vanguard Total International Stock ETF
# 382          382   BNDX              Vanguard Total International Bond ETF
# 1811        1811   IBIT                          iShares Bitcoin Trust ETF
# 2008        2008   IUSB             iShares Core Total USD Bond Market ETF
# 3922        3922   VCIT      Vanguard Intermediate-Term Corporate Bond ETF
# 3054        3054    QQQ                        Invesco QQQ Trust, Series 1
# 2050        2050   IXUS    iShares Core MSCI Total International Stock ETF
# 3947        3947   VGIT            Vanguard Intermediate-Term Treasury ETF
# 3695        3695    TLT                 iShares 20+ Year Treasury Bond ETF
# 2094        2094   JEPQ       J.P. Morgan Nasdaq Equity Premium Income ETF
# 3928        3928   VCSH             Vanguard Short-Term Corporate Bond ETF
# 3101        3101   QYLD  Global X Funds Global X NASDAQ-100 Covered Cal...
# 2804        2804    PFF  iShares Trust iShares Preferred and Income Sec...
# 2379        2379    MBB                                    iShares MBS ETF
# 1892        1892   IGSB  iShares Trust iShares 1-5 Year Investment Grad...
# 1862        1862    IEF                iShares 7-10 Year Treasury Bond ETF
# 3760        3760   TSLL  Direxion Shares ETF Trust Direxion Daily TSLA ...
# 3951        3951   VGSH                   Vanguard Short-Term Treasury ETF
# 2790        2790   PDBC  Invesco Actively Managed Exch-Traded Commodity...
# 3972        3972   VMBS            Vanguard Mortgage-Backed Securities ETF
# 4020        4020   VTIP  Vanguard Short-Term Inflation-Protected Securi...
# 1884        1884   IGIB  iShares Trust iShares 5-10 Year Investment Gra...
# 3872        3872   USIG  iShares Broad USD Investment Grade Corporate B...
# 3364        3364    SHY                 iShares 1-3 Year Treasury Bond ETF
# 3984        3984   VONG                   Vanguard Russell 1000 Growth ETF
# 3742        3742   TQQQ                            ProShares  UltraPro QQQ
# 3062        3062   QQQM                             Invesco NASDAQ 100 ETF
# 3127        3127   RDVY          First Trust Rising Dividend Achievers ETF
# 3315        3315   SDVY  First Trust SMID Cap Rising Dividend Achievers...
# 2010        2010   IUSV                    iShares Core S&P U.S. Value ETF
stocks     us             XNAS  ETF    True           usd  1100663.0
# 3947  stocks     us             XNAS  ETF    True           usd  1021882.0
# 3695  stocks     us             XNAS  ETF    True           usd  1100663.0
# 2094  stocks     us             XNAS  ETF    True           usd  1485894.0
# 3928  stocks     us             XNAS  ETF    True           usd  1021882.0
# 3101  stocks     us             XNAS  ETF    True           usd  1432353.0
# 2804  stocks     us             XNAS  ETF    True           usd  1100663.0
# 2379  stocks     us             XNAS  ETF    True           usd  1100663.0
# 1892  stocks     us             XNAS  ETF    True           usd  1100663.0
# 1862  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3760  stocks     us             XNAS  ETF    True           usd        NaN
# 3951  stocks     us             XNAS  ETF    True           usd  1021882.0
# 2790  stocks     us             XNAS  ETF    True           usd  1595386.0
# 3972  stocks     us             XNAS  ETF    True           usd  1021882.0
# 4020  stocks     us             XNAS  ETF    True           usd   836906.0
# 1884  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3872  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3364  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3984  stocks     us             XNAS  ETF    True           usd  1021882.0
# 3742  stocks     us             XNAS  ETF    True           usd  1174610.0
# 3062  stocks     us             XNAS  ETF    True           usd   914208.0
# 3127  stocks     us             XNAS  ETF    True           usd  1552740.0
# 3315  stocks     us             XNAS  ETF    True           usd  1552740.0
# 2010  stocks     us             XNAS  ETF    True           usd  1100663.0
# 413   stocks     us             XNAS  ETF    True           usd  1657201.0
# 414   stocks     us             XNAS  ETF    True           usd  1657201.0
# 1048  stocks     us             XNAS  ETF    True           usd   930667.0
# 3363  stocks     us             XNAS  ETF    True           usd  1100663.0
# 813   stocks     us             XNAS  ETF    True           usd  1350487.0
# 3949  stocks     us             XNAS  ETF    True           usd  1021882.0
# 3940  stocks     us             XNAS  ETF    True           usd        NaN
# 37    stocks     us             XNAS  ETF    True           usd  1100663.0
# 1022  stocks     us             XNAS  ETF    True           usd  1100663.0
# 2009  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3985  stocks     us             XNAS  ETF    True           usd  1021882.0
# 924   stocks     us             XNAS  ETF    True           usd  1100663.0
# 588   stocks     us             XNAS  ETF    True           usd  1125816.0
# 4038  stocks     us             XNAS  ETF    True           usd  1004655.0
# 412   stocks     us             XNAS  ETF    True           usd  1657201.0
# 1864  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3300  stocks     us             XNAS  ETF    True           usd  1100663.0
# 415   stocks     us             XNAS  ETF    True           usd  1657201.0
# 1881  stocks     us             XNAS  ETF    True           usd  1100663.0
# 1109  stocks     us             XNAS  ETF    True           usd  1100663.0
# 4024  stocks     us             XNAS  ETF    True           usd  1021882.0
# 2391  stocks     us             XNAS  ETF    True           usd  1100663.0
# 1083  stocks     us             XNAS  ETF    True           usd  1100663.0
# 416   stocks     us             XNAS  ETF    True           usd  1657201.0
# 3616  stocks     us             XNAS  ETF    True           usd        NaN
# 417   stocks     us             XNAS  ETF    True           usd  1657201.0
# 1082  stocks     us             XNAS  ETF    True           usd  1100663.0
# 2097  stocks     us             XNAS  ETF    True           usd  1485894.0
# 1837  stocks     us             XNAS  ETF    True           usd  1100663.0
# 2317  stocks     us             XNAS  ETF    True           usd  1517936.0
# 85    stocks     us             XNAS  ETF    True           usd  1432353.0
# 39    stocks     us             XNAS  ETF    True           usd  1100663.0
# 119   stocks     us             XNAS  ETF    True           usd  1137360.0
# 1447  stocks     us             XNAS  ETF    True           usd  1517936.0
# 1085  stocks     us             XNAS  ETF    True           usd  1100663.0
# 3417  stocks     us             XNAS  ETF    True           usd  1137360.0
# 2705  stocks     us             XNAS  ETF    True           usd        NaN
#
#       ... ticker_root   list_date locale.1  market.1  \
# 376   ...         BND  2018-07-26       us    stocks
# 4034  ...        VXUS  2011-01-28       us    stocks
# 382   ...        BNDX  2013-06-04       us    stocks
# 1811  ...        IBIT  2024-01-11       us    stocks
# 2008  ...        IUSB  2017-08-02       us    stocks
# 3922  ...        VCIT  2009-11-23       us    stocks
# 3054  ...         QQQ  2011-03-23       us    stocks
# 2050  ...        IXUS  2016-02-02       us    stocks
# 3947  ...        VGIT  2009-11-23       us    stocks
# 3695  ...         TLT  2016-02-02       us    stocks
# 2094  ...        JEPQ  2022-05-04       us    stocks
# 3928  ...        VCSH  2009-11-23       us    stocks
# 3101  ...        QYLD  2018-12-24       us    stocks
# 2804  ...         PFF  2017-08-02       us    stocks
# 2379  ...         MBB  2017-08-02       us    stocks
# 1892  ...        IGSB  2017-08-02       us    stocks
# 1862  ...         IEF  2017-08-02       us    stocks
# 3760  ...        TSLL  2022-08-09       us    stocks
# 3951  ...        VGSH  2009-11-23       us    stocks
# 2790  ...        PDBC  2014-11-07       us    stocks
# 3972  ...        VMBS  2009-11-23       us    stocks
# 4020  ...        VTIP  2012-10-16       us    stocks
# 1884  ...        IGIB  2017-08-02       us    stocks
# 3872  ...        USIG  2017-08-02       us    stocks
# 3364  ...         SHY  2017-08-02       us    stocks
# 3984  ...        VONG  2010-09-22       us    stocks
# 3742  ...        TQQQ  2010-02-11       us    stocks
# 3062  ...        QQQM  2020-10-13       us    stocks
# 3127  ...        RDVY  2014-01-07       us    stocks
# 3315  ...        SDVY  2017-11-02       us    stocks
# 2010  ...        IUSV  2017-08-02       us    stocks
# 413   ...        BSCQ  2019-12-31       us    stocks
# 414   ...        BSCR  2019-12-31       us    stocks
# 1048  ...        EMXC  2017-07-20       us    stocks
# 3363  ...         SHV  2017-08-02       us    stocks
# 813   ...        DGRW  2013-05-22       us    stocks
# 3949  ...        VGLT  2009-11-23       us    stocks
# 3940  ...        VFLO  2023-06-22       us    stocks
# 37    ...        ACWI  2008-03-28       us    stocks
# 1022  ...         EMB  2017-08-02       us    stocks
# 2009  ...        IUSG  2017-08-02       us    stocks
# 3985  ...        VONV  2010-09-22       us    stocks
# 924   ...         DVY  2017-08-02       us    stocks
# 588   ...        CIBR  2015-07-07       us    stocks
# 4038  ...        VYMI  2016-03-02       us    stocks
# 412   ...        BSCP  2019-12-31       us    stocks
# 1864  ...         IEI  2017-08-02       us    stocks
# 3300  ...         SCZ  2016-02-02       us    stocks
# 415   ...        BSCS  2019-12-31       us    stocks
# 1881  ...         IGF  2016-02-02       us    stocks
# 1109  ...        EUFN  2010-01-22       us    stocks
# 4024  ...        VTWO  2010-09-22       us    stocks
# 2391  ...        MCHI  2016-02-02       us    stocks
# 1083  ...        ESGE  2016-06-30       us    stocks
# 416   ...        BSCT  2019-12-31       us    stocks
# 3616  ...        TBIL  2022-08-09       us    stocks
# 417   ...        BSCU  2020-09-16       us    stocks
# 1082  ...        ESGD  2016-06-30       us    stocks
# 2097  ...        JGLO  2023-09-14       us    stocks
# 1837  ...        ICLN  2008-06-25       us    stocks
# 2317  ...        LMBS  2014-11-05       us    stocks
# 85    ...         AIQ  2018-05-15       us    stocks
# 39    ...        ACWX  2008-03-28       us    stocks
# 119   ...        ANGL  2019-12-11       us    stocks
# 1447  ...        FTSM  2014-08-06       us    stocks
# 1085  ...        ESGU  2016-12-02       us    stocks
# 3417  ...         SMH  2019-12-11       us    stocks
# 2705  ...        ONEQ  2003-10-01       us    stocks
#
#                                                  name.1 primary_exchange.1  \
# 376                          Vanguard Total Bond Market               XNAS
# 4034             Vanguard Total International Stock ETF               XNAS
# 382               Vanguard Total International Bond ETF               XNAS
# 1811                          iShares Bitcoin Trust ETF               XNAS
# 2008             iShares Core Total USD Bond Market ETF               XNAS
# 3922      Vanguard Intermediate-Term Corporate Bond ETF               XNAS
# 3054                        Invesco QQQ Trust, Series 1               XNAS
# 2050    iShares Core MSCI Total International Stock ETF               XNAS
# 3947            Vanguard Intermediate-Term Treasury ETF               XNAS
# 3695                 iShares 20+ Year Treasury Bond ETF               XNAS
# 2094       J.P. Morgan Nasdaq Equity Premium Income ETF               XNAS
# 3928             Vanguard Short-Term Corporate Bond ETF               XNAS
# 3101  Global X Funds Global X NASDAQ-100 Covered Cal...               XNAS
# 2804  iShares Trust iShares Preferred and Income Sec...               XNAS
# 2379                                    iShares MBS ETF               XNAS
# 1892  iShares Trust iShares 1-5 Year Investment Grad...               XNAS
# 1862                iShares 7-10 Year Treasury Bond ETF               XNAS
# 3760  Direxion Shares ETF Trust Direxion Daily TSLA ...               XNAS
# 3951                   Vanguard Short-Term Treasury ETF               XNAS
# 2790  Invesco Actively Managed Exch-Traded Commodity...               XNAS
# 3972            Vanguard Mortgage-Backed Securities ETF               XNAS
# 4020  Vanguard Short-Term Inflation-Protected Securi...               XNAS
# 1884  iShares Trust iShares 5-10 Year Investment Gra...               XNAS
# 3872  iShares Broad USD Investment Grade Corporate B...               XNAS
# 3364                 iShares 1-3 Year Treasury Bond ETF               XNAS
# 3984                   Vanguard Russell 1000 Growth ETF               XNAS
# 3742                            ProShares  UltraPro QQQ               XNAS
# 3062                             Invesco NASDAQ 100 ETF               XNAS
# 3127          First Trust Rising Dividend Achievers ETF               XNAS
# 3315  First Trust SMID Cap Rising Dividend Achievers...               XNAS
# 2010                    iShares Core S&P U.S. Value ETF               XNAS
# 413        Invesco BulletShares 2026 Corporate Bond ETF               XNAS
# 414        Invesco BulletShares 2027 Corporate Bond ETF               XNAS
# 1048         iShares MSCI Emerging Markets ex China ETF               XNAS
# 3363                    iShares Short Treasury Bond ETF               XNAS
# 813   WisdomTree Trust WisdomTree U.S. Quality Divid...               XNAS
# 3949                    Vanguard Long-Term Treasury ETF               XNAS
# 3940                   VictoryShares Free Cash Flow ETF               XNAS
# 37                                iShares MSCI ACWI ETF               XNAS
# 1022  iShares J.P. Morgan USD Emerging Markets Bond ETF               XNAS
# 2009                   iShares Core S&P U.S. Growth ETF               XNAS
# 3985                    Vanguard Russell 1000 Value ETF               XNAS
# 924                         iShares Select Dividend ETF               XNAS
# 588   First Trust Exchange-Traded Fund II First Trus...               XNAS
# 4038     Vanguard International High Dividend Yield ETF               XNAS
# 412        Invesco BulletShares 2025 Corporate Bond ETF               XNAS
# 1864                 iShares 3-7 Year Treasury Bond ETF               XNAS
# 3300                    iShares MSCI EAFE Small-Cap ETF               XNAS
# 415        Invesco BulletShares 2028 Corporate Bond ETF               XNAS
# 1881                  iShares Global Infrastructure ETF               XNAS
# 1109                 iShares MSCI Europe Financials ETF               XNAS
# 4024                          Vanguard Russell 2000 ETF               XNAS
# 2391                             iShares MSCI China ETF               XNAS
# 1083        iShares, Inc. iShares ESG Aware MSCI EM ETF               XNAS
# 416        Invesco BulletShares 2029 Corporate Bond ETF               XNAS
# 3616                       US Treasury 3 Month Bill ETF               XNAS
# 417        Invesco BulletShares 2030 Corporate Bond ETF               XNAS
# 1082      iShares Trust iShares ESG Aware MSCI EAFE ETF               XNAS
# 2097                  JPMorgan Global Select Equity ETF               XNAS
# 1837                    iShares Global Clean Energy ETF               XNAS
# 2317  First Trust Exchange-Traded Fund IV First Trus...               XNAS
# 85    Global X Funds Global X Artificial Intelligenc...               XNAS
# 39                          iShares MSCI ACWI ex US ETF               XNAS
# 119             VanEck Fallen Angel High Yield Bond ETF               XNAS
# 1447            First Trust Enhanced Short Maturity ETF               XNAS
# 1085       iShares Trust iShares ESG Aware MSCI USA ETF               XNAS
# 3417                           VanEck Semiconductor ETF               XNAS
# 2705                Fidelity Nasdaq Composite Index ETF               XNAS
#
#      share_class_figi.1 share_class_shares_outstanding ticker.1 type.1
# 376        BBG001SK7DK4                   1.840823e+09      BND    ETF
# 4034       BBG001TJR1D8                   1.441790e+09     VXUS    ETF
# 382        BBG004N1LGK2                   1.400806e+09     BNDX    ETF
# 1811       BBG01KYQ6QS5                   1.347600e+09     IBIT    ETF
# 2008       BBG006MJCSW0                   7.140000e+08     IUSB    ETF
# 3922       BBG001T62M38                   6.873882e+08     VCIT    ETF
# 3054       BBG001S9GN63                   6.353500e+08      QQQ    ETF
# 2050       BBG003H6TMV7                   6.007000e+08     IXUS    ETF
# 3947       BBG001T62M92                   5.495645e+08     VGIT    ETF
# 3695       BBG001S8MLN3                   5.379000e+08      TLT    ETF
# 2094       BBG016NKZFF7                   5.325250e+08     JEPQ    ETF
# 3928       BBG001T62KZ7                   4.928535e+08     VCSH    ETF
# 3101       BBG00MVW9603                   4.837200e+08     QYLD    ETF
# 2804       BBG001SNVWC8                   4.635000e+08      PFF    ETF
# 2379       BBG001SSD8B1                   4.350000e+08      MBB    ETF
# 1892       BBG001SSD858                   4.032500e+08     IGSB    ETF
# 1862       BBG001S80936                   3.994000e+08      IEF    ETF
# 119        BBG002VZY7Y3                   1.042000e+08     ANGL    ETF
# 1447       BBG006XT8631                   1.029497e+08     FTSM    ETF
# 1085       BBG00FFPFTS4                   1.023500e+08     ESGU    ETF
# 3417       BBG002D68GN8                   1.017419e+08      SMH    ETF
# 2705       BBG001SBT983                   1.006000e+08     ONEQ    ETF
#
# [68 rows x 27 columns]

# %%
selected_etfs = xnas[xnas.ticker.isin(["AIQ", "SMH"])]
selected_etfs.to_dict()
# Out:
# {'Unnamed: 0': {85: 85, 3417: 3417},
#  'ticker': {85: 'AIQ', 3417: 'SMH'},
#  'name': {85: 'Global X Funds Global X Artificial Intelligence & Technology ETF',
#   3417: 'VanEck Semiconductor ETF'},
#  'market': {85: 'stocks', 3417: 'stocks'},
#  'locale': {85: 'us', 3417: 'us'},
#  'primary_exchange': {85: 'XNAS', 3417: 'XNAS'},
#  'type': {85: 'ETF', 3417: 'ETF'},
#  'active': {85: True, 3417: True},
#  'currency_name': {85: 'usd', 3417: 'usd'},
#  'cik': {85: 1432353.0, 3417: 1137360.0},
#  'composite_figi': {85: 'BBG00KX8KG94', 3417: 'BBG000BV7ZQ5'},
#  'share_class_figi': {85: 'BBG00KX8KH01', 3417: 'BBG002D68GN8'},
#  'last_updated_utc': {85: '2025-09-27T06:05:21.555455823Z',
#   3417: '2025-09-27T06:05:21.556744511Z'},
#  'active.1': {85: True, 3417: True},
#  'cik.1': {85: 1432353.0, 3417: 1137360.0},
#  'composite_figi.1': {85: 'BBG00KX8KG94', 3417: 'BBG000BV7ZQ5'},
#  'currency_name.1': {85: 'usd', 3417: 'usd'},
#  'ticker_root': {85: 'AIQ', 3417: 'SMH'},
#  'list_date': {85: '2018-05-15', 3417: '2019-12-11'},
#  'locale.1': {85: 'us', 3417: 'us'},
#  'market.1': {85: 'stocks', 3417: 'stocks'},
#  'name.1': {85: 'Global X Funds Global X Artificial Intelligence & Technology ETF',
#   3417: 'VanEck Semiconductor ETF'},
#  'primary_exchange.1': {85: 'XNAS', 3417: 'XNAS'},
#  'share_class_figi.1': {85: 'BBG00KX8KH01', 3417: 'BBG002D68GN8'},
#  'share_class_shares_outstanding': {85: 107980002.0, 3417: 101741874.0},
#  'ticker.1': {85: 'AIQ', 3417: 'SMH'},
#  'type.1': {85: 'ETF', 3417: 'ETF'}}

# %%
aiq = pd.read_csv("AIQ_Details.csv", index_col=0)

# %%
aiq[:20]
# Out:
#     % of Net Assets Ticker                    Name    SEDOL  Market Price ($)  \
# 0              3.86   BABA         ALIBABA GRP-ADR  BP41ZD1            171.91
# 1              3.64   TSLA               TESLA INC  B616C79            440.40
# 2              3.57  GOOGL       ALPHABET INC-CL A  BYVY8G0            246.54
# 4              3.28   AAPL               APPLE INC  2046251            255.46
# 6              3.24   AVGO            BROADCOM INC  BDZ78H9            334.53
# 7              3.23   ORCL             ORACLE CORP  2661568            283.46
# 8              3.16   PLTR        PALANTIR TECHN-A  BN78DQ4            177.57
# 9              3.13    TSM        TAIWAN SEMIC-ADR  2113382            273.36
# 10             2.87   META      META PLATFORMS INC  B7TL820            743.75
# 11             2.87   NVDA             NVIDIA CORP  2379504            178.19
# 12             2.82   NFLX             NETFLIX INC  2857817           1210.61
# 13             2.79   MSFT          MICROSOFT CORP  2588173            511.46
# 14             2.78    IBM                     IBM  2005973            284.31
# 15             2.77    AMD  ADVANCED MICRO DEVICES  2007849            159.46
# 16             2.69   CSCO       CISCO SYSTEMS INC  2198163             67.22
# 17             2.65   AMZN          AMAZON.COM INC  2000019            219.78
# 18             2.50    CRM          SALESFORCE INC  2310525            243.43
# 20             2.04    APP   APPLOVIN CORP-CLASS A  BMV3LG4            669.86
# 21             2.04   UBER   UBER TECHNOLOGIES INC  BK6N347             98.45
# 22             1.92    NOW          SERVICENOW INC  B80NXX8            936.00
#
#      Shares Held Market Value ($)  active  \
# 0   1,326,697.00   228,072,481.27    True
# 1     488,397.00   215,090,038.80    True
# 2     855,241.00   210,851,116.14    True
# 4     759,507.00   194,023,658.22    True
# 6     571,861.00   191,304,660.33    True
# 7     672,215.00   190,546,063.90    True
# 8   1,051,209.00   186,663,182.13    True
# 9     676,414.00   184,904,531.04    True
# 10    228,183.00   169,711,106.25    True
# 11    952,419.00   169,711,541.61    True
# 12    137,788.00   166,807,530.68    True
# 13    322,413.00   164,901,352.98    True
# 14    577,160.00   164,092,359.60    True
# 15  1,025,162.00   163,472,332.52    True
# 16  2,368,660.00   159,221,325.20    True
# 17    712,212.00   156,529,953.36    True
# 18    607,364.00   147,850,618.52    True
# 20    180,347.00   120,807,241.42    True
# 21  1,223,666.00   120,469,917.70    True
# 22    121,211.00   113,453,496.00    True
#
#                                               address  \
# 0                                                 NaN
# 1   {'address1': '1 TESLA ROAD', 'address2': None,...
# 2   {'address1': '1600 AMPHITHEATRE PARKWAY', 'add...
# 4   {'address1': 'ONE APPLE PARK WAY', 'address2':...
# 6   {'address1': '3421 HILLVIEW AVENUE', 'address2...
# 7   {'address1': '2300 ORACLE WAY', 'address2': No...
# 8   {'address1': '1200 17TH STREET', 'address2': '...
# 9                                                 NaN
# 10  {'address1': '1 META WAY', 'address2': None, '...
# 11  {'address1': '2788 SAN TOMAS EXPRESSWAY', 'add...
# 12  {'address1': '121 ALBRIGHT WAY', 'address2': N...
# 13  {'address1': 'ONE MICROSOFT WAY', 'address2': ...
# 14  {'address1': '1 NEW ORCHARD ROAD', 'address2':...
# 15  {'address1': '2485 AUGUSTINE DRIVE', 'address2...
# 16  {'address1': '170 WEST TASMAN DR', 'address2':...
# 17  {'address1': '410 TERRY AVENUE NORTH', 'addres...
# 18  {'address1': 'SALESFORCE TOWER', 'address2': '...
# 20  {'address1': '1100 PAGE MILL RD', 'address2': ...
# 21  {'address1': '1725 3RD STREET', 'address2': No...
# 22  {'address1': '2225 LAWSON LANE', 'address2': N...
#
#                                              branding  ...    phone_number  \
# 0   {'icon_url': 'https://api.polygon.io/v1/refere...  ...             NaN
# 1   {'icon_url': 'https://api.polygon.io/v1/refere...  ...    512-516-8177
# 2   {'icon_url': 'https://api.polygon.io/v1/refere...  ...    650-253-0000
# 4   {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (408) 996-1010
# 6   {'icon_url': 'https://api.polygon.io/v1/refere...  ...    650-427-6000
# 7   {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (737) 867-1000
# 8   {'icon_url': 'https://api.polygon.io/v1/refere...  ...    720-358-3679
# 9   {'icon_url': 'https://api.polygon.io/v1/refere...  ...             NaN
# 10  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    650-543-4800
# 11  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    408-486-2000
# 12  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    408-540-3700
# 13  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    425-882-8080
# 14  {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (914) 499-1900
# 15  {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (408) 749-4000
# 16  {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (408) 526-4000
# 17  {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (206) 266-1000
# 18  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    415-901-7000
# 20  {'icon_url': 'https://api.polygon.io/v1/refere...  ...  (800) 839-9646
# 21  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    415-612-8582
# 22  {'icon_url': 'https://api.polygon.io/v1/refere...  ...    408-501-8550
#
#    primary_exchange share_class_figi  share_class_shares_outstanding  \
# 0              XNYS     BBG006G2JWB1                    2.384079e+09
# 1              XNAS     BBG001SQKGD7                    3.325151e+09
# 2              XNAS     BBG009S39JY5                    5.817000e+09
# 4              XNAS     BBG001S5N8V8                    1.484039e+10
# 6              XNAS     BBG00KHY5SY8                    4.722365e+09
# 7              XNYS     BBG001S5SJG6                    2.841714e+09
# 8              XNAS     BBG001T53796                    2.274262e+09
# 9              XNYS     BBG001S5WWW4                    5.186523e+09
# 10             XNAS     BBG001SQCQC5                    2.168962e+09
# 11             XNAS     BBG001S5TZJ6                    2.430000e+10
# 12             XNAS     BBG001SF6L46                    4.249263e+08
# 13             XNAS     BBG001S5TD05                    7.433166e+09
# 14             XNYS     BBG001S5S399                    9.293966e+08
# 15             XNAS     BBG001S5NN36                    1.622844e+09
# 16             XNAS     BBG001S6HC62                    3.953197e+09
# 17             XNAS     BBG001S5PQL7                    1.066491e+10
# 18             XNYS     BBG001SDLP09                    9.520000e+08
# 20             XNAS     BBG006HFPX86                    3.076364e+08
# 21             XNYS     BBG002B04MW4                    2.085419e+09
# 22             XNYS     BBG001T4JFC0                    2.080000e+08
#
#     sic_code                                    sic_description  ticker  \
# 0        NaN                                                NaN    BABA
# 1     3711.0              MOTOR VEHICLES & PASSENGER CAR BODIES    TSLA
# 2     7370.0  SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING...   GOOGL
# 4     3571.0                               ELECTRONIC COMPUTERS    AAPL
# 6     3674.0                   SEMICONDUCTORS & RELATED DEVICES    AVGO
# 7     7372.0                      SERVICES-PREPACKAGED SOFTWARE    ORCL
# 8     7372.0                      SERVICES-PREPACKAGED SOFTWARE    PLTR
# 9        NaN                                                NaN     TSM
# 10    7370.0  SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING...    META
# 11    3674.0                   SEMICONDUCTORS & RELATED DEVICES    NVDA
# 12    7841.0                         SERVICES-VIDEO TAPE RENTAL    NFLX
# 13    7372.0                      SERVICES-PREPACKAGED SOFTWARE    MSFT
# 14    3570.0                        COMPUTER & OFFICE EQUIPMENT     IBM
# 15    3674.0                   SEMICONDUCTORS & RELATED DEVICES     AMD
# 16    3576.0                  COMPUTER COMMUNICATIONS EQUIPMENT    CSCO
# 17    5961.0                 RETAIL-CATALOG & MAIL-ORDER HOUSES    AMZN
# 18    7372.0                      SERVICES-PREPACKAGED SOFTWARE     CRM
# 20    7370.0  SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING...     APP
# 21    7389.0                    SERVICES-BUSINESS SERVICES, NEC    UBER
# 22    7372.0                      SERVICES-PREPACKAGED SOFTWARE     NOW
#
#    total_employees  type weighted_shares_outstanding
# 0         124320.0  ADRC                2.384498e+09
# 1         125665.0    CS                3.325151e+09
# 2         187103.0    CS                1.209400e+10
# 4         164000.0    CS                1.484039e+10
# 6          37000.0    CS                4.722365e+09
# 7         162000.0    CS                2.841714e+09
# 8           4164.0    CS                2.372342e+09
# 9          83825.0  ADRC                5.186523e+09
# 10         75945.0    CS                2.512141e+09
# 11         36000.0    CS                2.434700e+10
# 12         14000.0    CS                4.249263e+08
# 13        228000.0    CS                7.433166e+09
# 14        270300.0    CS                9.315192e+08
# 15         28000.0    CS                1.622844e+09
# 16         86200.0    CS                3.953197e+09
# 17       1556000.0    CS                1.066491e+10
# 18         76453.0    CS                9.520000e+08
# 20          1563.0    CS                3.382499e+08
# 21         32700.0    CS                2.085419e+09
# 22         26293.0    CS                2.075190e+08
#
# [20 rows x 36 columns]

# %%
tickers = "', '".join(aiq.Ticker.tolist() + ["AIQ"])
query = f"""
INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/aiq_trades.parquet')
SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2025-09-26_filtered.parquet')
WHERE ticker IN ('{tickers}')
SETTINGS max_threads=16, max_download_threads=16, max_insert_threads=16, s3_truncate_on_insert=1
"""
print(query)

query = f"""
INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/aiq_quotes.parquet')
SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_quotes/2025-09-26_filtered.parquet')
WHERE ticker IN ('{tickers}')
SETTINGS max_threads=16, max_download_threads=16, max_insert_threads=16, s3_truncate_on_insert=1
"""
print(query)
# Out:
# INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/aiq_trades.parquet')
# SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2025-09-26_filtered.parquet')
# WHERE ticker IN ('BABA', 'TSLA', 'GOOGL', 'AAPL', 'AVGO', 'ORCL', 'PLTR', 'TSM', 'META', 'NVDA', 'NFLX', 'MSFT', 'IBM', 'AMD', 'CSCO', 'AMZN', 'CRM', 'APP', 'UBER', 'NOW', 'QCOM', 'MU', 'SHOP', 'INTC', 'ADBE', 'ACN', 'CDNS', 'SNPS', 'SNOW', 'MRVL', 'TRI', 'FTNT', 'NXPI', 'WDAY', 'ZS', 'STX', 'CRWV', 'DDOG', 'HUT', 'BIDU', 'PONY', 'STNE', 'CYBR', 'SOUN', 'AMBA', 'GEHC', 'QUBT', 'WIX', 'HPE', 'ERIC', 'INFA', 'PEGA', 'WRD', 'TDC', 'SMCI', 'PATH', 'OKTA', 'DXC', 'CCCS', 'VRNT', 'G', 'NICE', 'ZBRA', 'SNAP', 'TTD', 'TWLO', 'AI', 'AIQ')
# SETTINGS max_threads=16, max_download_threads=16, max_insert_threads=16, s3_truncate_on_insert=1
#
#
# INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/aiq_quotes.parquet')
# SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_quotes/2025-09-26_filtered.parquet')
# WHERE ticker IN ('BABA', 'TSLA', 'GOOGL', 'AAPL', 'AVGO', 'ORCL', 'PLTR', 'TSM', 'META', 'NVDA', 'NFLX', 'MSFT', 'IBM', 'AMD', 'CSCO', 'AMZN', 'CRM', 'APP', 'UBER', 'NOW', 'QCOM', 'MU', 'SHOP', 'INTC', 'ADBE', 'ACN', 'CDNS', 'SNPS', 'SNOW', 'MRVL', 'TRI', 'FTNT', 'NXPI', 'WDAY', 'ZS', 'STX', 'CRWV', 'DDOG', 'HUT', 'BIDU', 'PONY', 'STNE', 'CYBR', 'SOUN', 'AMBA', 'GEHC', 'QUBT', 'WIX', 'HPE', 'ERIC', 'INFA', 'PEGA', 'WRD', 'TDC', 'SMCI', 'PATH', 'OKTA', 'DXC', 'CCCS', 'VRNT', 'G', 'NICE', 'ZBRA', 'SNAP', 'TTD', 'TWLO', 'AI', 'AIQ')
# SETTINGS max_threads=16, max_download_threads=16, max_insert_threads=16, s3_truncate_on_insert=1

# %%
len(tickers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 len(tickers)
#
# NameError: name 'tickers' is not defined

# %%
INSERT INTO FUNCTION s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/Alphathon/aiq_trades.parquet')
SELECT * FROM s3('https://s3.us-east-005.backblazeb2.com/GregsMktData/all_trades/2025-09-26_filtered.parquet')
WHERE ticker IN ('BABA', 'TSLA', 'GOOGL', 'AAPL', 'AVGO', 'ORCL', 'PLTR', 'TSM', 'META', 'NVDA', 'NFLX', 'MSFT', 'IBM', 'AMD', 'CSCO', 'AMZN', 'CRM', 'APP', 'UBER', 'NOW', 'QCOM', 'MU', 'SHOP', 'INTC', 'ADBE', 'ACN', 'CDNS', 'SNPS', 'SNOW', 'MRVL', 'TRI', 'FTNT', 'NXPI', 'WDAY', 'ZS', 'STX', 'CRWV', 'DDOG', 'HUT', 'BIDU', 'PONY', 'STNE', 'CYBR', 'SOUN', 'AMBA', 'GEHC', 'QUBT', 'WIX', 'HPE', 'ERIC', 'INFA', 'PEGA', 'WRD', 'TDC', 'SMCI', 'PATH', 'OKTA', 'DXC', 'CCCS', 'VRNT', 'G', 'NICE', 'ZBRA', 'SNAP', 'TTD', 'TWLO', 'AI', 'AIQ')
SETTINGS max_threads=16, max_download_threads=16, max_insert_threads=16, s3_truncate_on_insert=1
